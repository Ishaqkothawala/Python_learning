# %%
#Python learning

#Chapter 1 - Print

name = "Hello - world"
print (name)
# Out:
# Hello - world

# %%
#Chapter 2 - variables for strings

name = "mark"
age = "65"
print (name,age)
# Out:
# mark 65

# %%
#chapter 3 = variable for numbers

Pakistan_1 = 50
India = 100
Pakistan_1 + India
#India + 20
# Out:
# 150
